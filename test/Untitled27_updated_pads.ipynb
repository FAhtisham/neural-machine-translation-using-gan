# %% [markdown]
# # Note:
# #### The models has been evaluated with two different accuracies
#
# 1- as used in paper (TP+TN/TP+TN+FN+FP)
#
# 2- Overall Accuray (TP/N)

# %% [markdown]
# # Implmentation of the RPCNet Paper

# %%
import torch
import torch.nn as nn
import torch.nn.functional as f
from torch.utils.data import TensorDataset, DataLoader

import sys
import numpy as np
from numpy import load
from tqdm import tqdm

from pycm import *

# %% [markdown]
# # Description of the Dataset

# %%
# Decription of the dataset
data = load('dataset.npz')
lst = data.files

print("x: Sequences \ny: Labels \n")

for item in lst:
    print(item)

print('Sequences: ',data['x'].shape,'|  Labels', data['y'].shape)
# Out:
# x: Sequences
# y: Labels
#
# x
# y
# Sequences:  (8920, 1182) |  Labels (8920,)

# %%
# temp = torch.zeros((16,16), dtype=torch.int)
# temp

# %% [markdown]
# # One Hot Encoding Conversion

# %%
'''
    One hot encoding function
    args: 'data'
            Type: a single np array (1182, 16)
    return: 'New Tensor'
            Takes the np array, finds the one hot encoding char
            Creates a new tensor and returns it (1182, 16, 16)
'''
def one_hot_encoded(data): #1182*16 to 1182*16*16
  new_tensor = torch.zeros((1182, 16,16))
  for i in range(data.shape[0]):
    row,col=data[i],data[i]
    new_tensor[i,row,col]=1
  return new_tensor

# %%
# Convert all the sequences to one hot encoded matrices of size 16*16

# Load the sequences
new_data = data['x'].astype(int)
sequences_n = torch.zeros(new_data.shape[0], new_data.shape[1], 16,16)

# Pass the sequences to one hot encoding function
for i in tqdm(range(new_data.shape[0])):
    sequences_n[i]=one_hot_encoded(new_data[i])
print(sequences_n.size())

# Load and convert the labels to torch tensor
labels = torch.from_numpy(data['y'].astype(np.int64))
# Out:
# 100%|███████████████████████████████████████| 8920/8920 [01:43<00:00, 86.08it/s]
# torch.Size([8920, 1182, 16, 16])

# %% [markdown]
# # Creation of Dataloaders

# %%
# Create the dataset
full_dataset = TensorDataset(sequences_n, labels)

# Split the dataset
train_ds, test_ds = torch.utils.data.random_split(full_dataset, (6320, 2600))

# Print and confirm the dataset
# print(train_ds, test_ds)
# print(len(train_ds.indices), len(test_ds))
# print(train_ds.indices, test_ds.indices)

# Create the train data loader
# Ignore if K-Fold training 
# train_dataloader = DataLoader(train_ds, batch_size=32, shuffle=False, sampler=None,
#            batch_sampler=None, num_workers=0, collate_fn=None,
#            pin_memory=False, drop_last=False, timeout=0,
#            worker_init_fn=None)

# Create the test data loader
test_dataloader = DataLoader(test_ds, batch_size=64, shuffle=False, sampler=None,
           batch_sampler=None, num_workers=0, collate_fn=None,
           pin_memory=False, drop_last=False, timeout=0,
           worker_init_fn=None)

# %% [markdown]
# # Creation of the Model

# %%
'''
    Type: RCPClass
    The class conatains the layers of the Dense and Transition blocks
    
    Args: Takes the dataset (batch size, sequence_size, w, h)
    return: Logits (Probabilities of the all 13 classes)
'''

# Create the RCPNet Class
class RPCNet(nn.Module):
  def __init__(self, in_channels):
    super(RPCNet, self).__init__()
    
    self.in_channels = in_channels
    self.conv1 = nn.Conv2d(in_channels=1182, out_channels=128, kernel_size=(16,17), padding=(4,6))
    
    # First Dense Net Block
    self.DenseBlock1 = DenseBlock(128)
    
    # Second Dense Net Block
    self.DenseBlock2 = DenseBlock(256)
    
    # Third Dense Net Block
    self.DenseBlock3 = DenseBlock(512)
    
    # Transition Block 1
    self.pos_dense1 = nn.Sequential(
          nn.BatchNorm2d(128),
          nn.ReLU(inplace=True),
          nn.Conv2d(in_channels=128,out_channels=256,kernel_size=(1,1),padding=(2,2)),
          nn.MaxPool2d((1,4)))
    
    # Transition Block 2
    self.pos_dense2 = nn.Sequential(
          nn.BatchNorm2d(256),
          nn.ReLU(inplace=True),
          nn.Conv2d(in_channels=256,out_channels=512,kernel_size=(1,1),padding=(2,2), stride=1),
          nn.MaxPool2d((1,4)))
    
    # Transition Block 3
    self.pos_dense3 = nn.Sequential(
          nn.BatchNorm2d(512),
          nn.ReLU(inplace=True),
          nn.Conv2d(in_channels=512,out_channels=1024,kernel_size=(1,1),padding=(2,2),stride=1),
          nn.MaxPool2d((1,4)))
    
    # Final linear layer, can be used with a Flatten Layer 
    self.f= nn.Flatten()
    self.Linear = nn.Linear(611328, 13)
      
  def forward(self, input):
    out = self.conv1(input)
    

    out= self.DenseBlock1(out)
    out= self.pos_dense1(out)

    out= self.DenseBlock2(out)
    out = self.pos_dense2(out)

    out= self.DenseBlock3(out)
    out = self.pos_dense3(out)
    
    logits = self.f(out)
    logits= self.Linear(logits)


    return logits

'''
    Type: Class DenseBlock
          Contains Batch Normalization, ReLU, Conv2D
          
    Input: Declaration: Num of input channels 
           Forward: Output of previous layer
    
    Can be used before transition blocks or other layers
'''
class DenseBlock(nn.Module):
  def __init__(self, num_features):
    super(DenseBlock, self).__init__()

    self.Block1 = Block(num_features) # applies relu and BN
    self.Block2 = Block(num_features)

  def forward(self, o_input):

    block1_res = self.Block1(o_input)
    block2_res = self.Block2((torch.cat((block1_res, o_input), dim=2))) # o_inpu (concat) block1res

    return  torch.cat((block1_res, block2_res, o_input), dim=2) # concat, block1_res, block2_res, o_input

'''
    Type: Block Class
    
    Input: Declaration: Num of input channels 
           Forward: Output of the previous layer
           
    return: Concatenated input and output of the BN, ReLU, Conv2D
'''

class Block(nn.Module):
  def __init__(self, num_features):
    super(Block, self).__init__()
    self.num_features = num_features

    self.BN = nn.BatchNorm2d(self.num_features) # try 2d
    self.conv1 = nn.Conv2d(in_channels=self.num_features, out_channels=num_features, kernel_size=(16,17), padding=(7,8))
  
  def forward(self, input):
    res_relu = f.relu(self.BN(input))
    res_relu_conv = self.conv1(res_relu)

    return res_relu_conv

# %% [markdown]
# # Initializaiton of Model, Optimizer, Loss function

# %%
device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")

# %%
model = RPCNet(1182)


model.cuda()
if torch.cuda.device_count() > 1:
    #  print("Let's use", torch.cuda.device_count(), "GPUs!")
    model = torch.nn.DataParallel(model)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_function = nn.CrossEntropyLoss()

# %%
model
# Out:
# DataParallel(
#   (module): RPCNet(
#     (conv1): Conv2d(1182, 128, kernel_size=(16, 17), stride=(1, 1), padding=(4, 6))
#     (DenseBlock1): DenseBlock(
#       (Block1): Block(
#         (BN): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(128, 128, kernel_size=(16, 17), stride=(1, 1), padding=(7, 8))
#       )
#       (Block2): Block(
#         (BN): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(128, 128, kernel_size=(16, 17), stride=(1, 1), padding=(7, 8))
#       )
#     )
#     (DenseBlock2): DenseBlock(
#       (Block1): Block(
#         (BN): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(256, 256, kernel_size=(16, 17), stride=(1, 1), padding=(7, 8))
#       )
#       (Block2): Block(
#         (BN): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(256, 256, kernel_size=(16, 17), stride=(1, 1), padding=(7, 8))
#       )
#     )
#     (DenseBlock3): DenseBlock(
#       (Block1): Block(
#         (BN): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(512, 512, kernel_size=(16, 17), stride=(1, 1), padding=(7, 8))
#       )
#       (Block2): Block(
#         (BN): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(512, 512, kernel_size=(16, 17), stride=(1, 1), padding=(7, 8))
#       )
#     )
#     (pos_dense1): Sequential(
#       (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): ReLU(inplace=True)
#       (2): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), padding=(2, 2))
#       (3): MaxPool2d(kernel_size=(1, 4), stride=(1, 4), padding=0, dilation=1, ceil_mode=False)
#     )
#     (pos_dense2): Sequential(
#       (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): ReLU(inplace=True)
#       (2): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=(2, 2))
#       (3): MaxPool2d(kernel_size=(1, 4), stride=(1, 4), padding=0, dilation=1, ceil_mode=False)
#     )
#     (pos_dense3): Sequential(
#       (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): ReLU(inplace=True)
#       (2): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), padding=(2, 2))
#       (3): MaxPool2d(kernel_size=(1, 4), stride=(1, 4), padding=0, dilation=1, ceil_mode=False)
#     )
#     (f): Flatten(start_dim=1, end_dim=-1)
#     (Linear): Linear(in_features=611328, out_features=13, bias=True)
#   )
# )

# %% [markdown]
# # Train Loop
# ### (Please ignore this part if K-Fold is of interest)
# ### (To run it please uncomment the train data loader that has been created in the dataset preprocessing part)

# %%
# total_loss_e = 0.0

# plot_loss = []
# for epoch in range(35):
#     total_loss_i = 0
#     total=0.0
#     correct=0.0
    
#     for i, batch in enumerate(train_dataloader):
#         x,y=batch
#         logits = model(x.cuda())
#         loss = loss_function(logits,y.cuda())
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()
#         total_loss_i += loss.item()
#         _, predicted = torch.max(logits.data, 1)
#         total += y.size(0)
#         correct += (predicted.cpu() == y).sum().item()
#         if i%50 ==0:
#             print("Iter : {}  Train Loss : {}".format(i,loss.item()))
#     total_loss_e+=total_loss_i/len(train_dataloader)
#     print("Epoch  {} :   Train Loss : {}  Accuracy : {}".format(epoch, total_loss_e, (100 * (correct / total))))
#     plot_loss.append(total_loss_e)
#     total_loss_e=0

# %%
# torch.save(model.state_dict(), "rpcnet.pt")

# %%
# import matplotlib.pyplot as plt
# plt.title("Train Loss")
# plt.xlabel("Epochs")
# plt.ylabel("Loss")
# plt.plot(plot_loss)
# plt.show()

# %% [markdown]
# # K-Fold Training

# %%
'''
    Type: Parameter reset function
    Return: None
    
    The funciton is used to reset the parameters of the model in K-Fold manner
'''

def reset_weights(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
        m.reset_parameters()

# %%
from sklearn.metrics import accuracy_score
validation_accuracy=[]
test_accuracy=[]

'''
    Type: Train function
    Return: None
    
    The funciton is used to train the model in K-Fold manner
'''
def train(fold, model, train_loader, epoch):
    model.train()
    total=0.0
    correct=0.0
    for batch_idx, batch in enumerate(train_loader):
        data, target = batch 
        data, target = data.cuda(), target.cuda()
        optimizer.zero_grad()
        output = model(data)
        loss = loss_function(output, target)
        loss.backward()
        optimizer.step()
        _, predicted = torch.max(output.data, 1)
        total += target.size(0)
        correct += (predicted == target).sum().item()
        
        if batch_idx % 100 == 0:
            cm = ConfusionMatrix(actual_vector = target.cpu().numpy().tolist(), predict_vector =predicted.cpu().numpy().tolist())
            print("Accuracy as in paper: ",(sum(cm.TP.values())+ sum(cm.TN.values()))/ (sum(cm.TP.values())+ sum(cm.TN.values())+sum(cm.FP.values())+sum(cm.FN.values())))
            print('Train Fold/Epoch: {}/{} [{}/{} ({:.0f}%)]\tLoss: {:.6f} , Overall Accuracy : {}'.format(
                fold,epoch, batch_idx * len(train_loader), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item(), (100 * (correct / total))))
'''
    Type: Validation function
    Return: Accuracies
    
    The funciton is used to validate the model in K-Fold manner
'''

def validate(fold, model, train_loader):
    model.eval()
    total=0.0
    correct=0.0
    for batch_idx, batch in enumerate(train_loader):
        data, target = batch 
        data, target = data.cuda(), target.cuda()
        output = model(data)
        loss = loss_function(output, target)
        _, predicted = torch.max(output.data, 1)
        total += target.size(0)
        correct += (predicted == target).sum().item()
        if batch_idx % 100 == 0:
            cm = ConfusionMatrix(actual_vector = target.cpu().numpy().tolist(), predict_vector =predicted.cpu().numpy().tolist())
            print("Accuracy as in paper: ",(sum(cm.TP.values())+ sum(cm.TN.values()))/ (sum(cm.TP.values())+ sum(cm.TN.values())+sum(cm.FP.values())+sum(cm.FN.values())))
            print('Validation Fold: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f} , Overall Accuracy : {}'.format(
                fold, batch_idx * len(train_loader), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item(), (100 * (correct / total))))
    print('Overall Accuracy: ',100 * (correct / total))
    cm = ConfusionMatrix(actual_vector = target.cpu().numpy().tolist(), predict_vector =predicted.cpu().numpy().tolist())
    validation_accuracy.append((sum(cm.TP.values())+ sum(cm.TN.values()))/ (sum(cm.TP.values())+ sum(cm.TN.values())+sum(cm.FP.values())+sum(cm.FN.values())) )
    
'''
    Type: Test function
    Return: None
    
    The funciton is used to test  the model, it prints the test accuracy

'''
           
def test(model, test_loader):
    total_loss_i = 0
    total=0.0
    correct=0.0
    model.eval()
    for i, batch in enumerate(test_dataloader):
        x,target=batch
        logits = model(x.cuda())
        loss = loss_function(logits,target.cuda())
        total_loss_i += loss.item()
        _, predicted = torch.max(logits.data, 1)
        total += target.size(0)
        correct += (predicted.cpu() == target).sum().item()

    # total_loss_e+=total_loss_i/len(test_dataloader)
    print("Overall Test Accuracy : {}".format( (100 * (correct / total))))
    cm = ConfusionMatrix(actual_vector = target.cpu().numpy().tolist(), predict_vector =predicted.cpu().numpy().tolist())
    print("Accuracy as in paper: ",((sum(cm.TP.values())+ sum(cm.TN.values()))/ (sum(cm.TP.values())+ sum(cm.TN.values())+sum(cm.FP.values())+sum(cm.FN.values())) ))

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

kfolds = 5

kfold = KFold(n_splits=kfolds, shuffle = True)
val_id = 4
for i in range(1,kfolds+1):
    for fold,(train_idx, test_idx) in enumerate(kfold.split(train_ds),1 ):   

        print('------------fold no---------{}----------------------'.format(fold))
        train_subsampler = torch.utils.data.SubsetRandomSampler(train_idx)
        train_dataloader = DataLoader(train_ds, batch_size=64, sampler=train_subsampler)
        

        if fold == i:
            continue
        for epoch in range(1, 9+1):
            train(fold, model, train_dataloader, epoch)
    print("validate",i)
    validate(i, model, train_dataloader)
    test(model, test_dataloader)
    model.apply(reset_weights)
# Out:
# ------------fold no---------1----------------------
# ------------fold no---------2----------------------
# Accuracy as in paper:  0.8653846153846154
# Train Fold/Epoch: 2/1 [0/6320 (0%)]	Loss: 2.604637 , Overall Accuracy : 12.5
# Accuracy as in paper:  0.8822115384615384
# Train Fold/Epoch: 2/2 [0/6320 (0%)]	Loss: 2.474325 , Overall Accuracy : 23.4375
# Accuracy as in paper:  0.8701923076923077
# Train Fold/Epoch: 2/3 [0/6320 (0%)]	Loss: 2.302255 , Overall Accuracy : 15.625
# Accuracy as in paper:  0.8846153846153846
# Train Fold/Epoch: 2/4 [0/6320 (0%)]	Loss: 2.067981 , Overall Accuracy : 25.0
# Accuracy as in paper:  0.9038461538461539
# Train Fold/Epoch: 2/5 [0/6320 (0%)]	Loss: 1.714582 , Overall Accuracy : 37.5
# Accuracy as in paper:  0.9038461538461539
# Train Fold/Epoch: 2/6 [0/6320 (0%)]	Loss: 1.650898 , Overall Accuracy : 37.5
# Accuracy as in paper:  0.8942307692307693
# Train Fold/Epoch: 2/7 [0/6320 (0%)]	Loss: 1.862810 , Overall Accuracy : 31.25
# Accuracy as in paper:  0.8990384615384616
# Train Fold/Epoch: 2/8 [0/6320 (0%)]	Loss: 1.677992 , Overall Accuracy : 34.375
# Accuracy as in paper:  0.9038461538461539
# Train Fold/Epoch: 2/9 [0/6320 (0%)]	Loss: 1.655513 , Overall Accuracy : 37.5
# ------------fold no---------3----------------------
# Accuracy as in paper:  0.9086538461538461
# Train Fold/Epoch: 3/1 [0/6320 (0%)]	Loss: 1.508901 , Overall Accuracy : 40.625
# Accuracy as in paper:  0.9206730769230769
# Train Fold/Epoch: 3/2 [0/6320 (0%)]	Loss: 1.388973 , Overall Accuracy : 48.4375
# Accuracy as in paper:  0.9278846153846154
# Train Fold/Epoch: 3/3 [0/6320 (0%)]	Loss: 1.271156 , Overall Accuracy : 53.125
# Accuracy as in paper:  0.9495192307692307
# Train Fold/Epoch: 3/4 [0/6320 (0%)]	Loss: 1.345222 , Overall Accuracy : 67.1875
# Accuracy as in paper:  0.9471153846153846
# Train Fold/Epoch: 3/5 [0/6320 (0%)]	Loss: 0.977240 , Overall Accuracy : 65.625
# Accuracy as in paper:  0.9326923076923077
# Train Fold/Epoch: 3/6 [0/6320 (0%)]	Loss: 1.026597 , Overall Accuracy : 56.25
# Accuracy as in paper:  0.9375
# Train Fold/Epoch: 3/7 [0/6320 (0%)]	Loss: 0.974696 , Overall Accuracy : 59.375
# Accuracy as in paper:  0.9567307692307693
# Train Fold/Epoch: 3/8 [0/6320 (0%)]	Loss: 0.886411 , Overall Accuracy : 71.875
# Accuracy as in paper:  0.9471153846153846
# Train Fold/Epoch: 3/9 [0/6320 (0%)]	Loss: 0.793637 , Overall Accuracy : 65.625
# ------------fold no---------4----------------------
# Accuracy as in paper:  0.9567307692307693
# Train Fold/Epoch: 4/1 [0/6320 (0%)]	Loss: 0.819322 , Overall Accuracy : 71.875
# Accuracy as in paper:  0.9591346153846154
# Train Fold/Epoch: 4/2 [0/6320 (0%)]	Loss: 0.713356 , Overall Accuracy : 73.4375
# Accuracy as in paper:  0.9519230769230769
# Train Fold/Epoch: 4/3 [0/6320 (0%)]	Loss: 0.693849 , Overall Accuracy : 68.75
# Accuracy as in paper:  0.9639423076923077
# Train Fold/Epoch: 4/4 [0/6320 (0%)]	Loss: 0.516993 , Overall Accuracy : 76.5625
# Accuracy as in paper:  0.96875
# Train Fold/Epoch: 4/5 [0/6320 (0%)]	Loss: 0.538674 , Overall Accuracy : 79.6875
# Accuracy as in paper:  0.9447115384615384
# Train Fold/Epoch: 4/6 [0/6320 (0%)]	Loss: 0.863867 , Overall Accuracy : 64.0625
# Accuracy as in paper:  0.96875
# Train Fold/Epoch: 4/7 [0/6320 (0%)]	Loss: 0.538758 , Overall Accuracy : 79.6875
# Accuracy as in paper:  0.9735576923076923
# Train Fold/Epoch: 4/8 [0/6320 (0%)]	Loss: 0.484073 , Overall Accuracy : 82.8125
# Accuracy as in paper:  0.9543269230769231
# Train Fold/Epoch: 4/9 [0/6320 (0%)]	Loss: 0.655937 , Overall Accuracy : 70.3125
# ------------fold no---------5----------------------
# Accuracy as in paper:  0.9663461538461539
# Train Fold/Epoch: 5/1 [0/6320 (0%)]	Loss: 0.594406 , Overall Accuracy : 78.125
# Accuracy as in paper:  0.9903846153846154
# Train Fold/Epoch: 5/2 [0/6320 (0%)]	Loss: 0.260776 , Overall Accuracy : 93.75
# Accuracy as in paper:  0.9759615384615384
# Train Fold/Epoch: 5/3 [0/6320 (0%)]	Loss: 0.402451 , Overall Accuracy : 84.375
# Accuracy as in paper:  0.9855769230769231
# Train Fold/Epoch: 5/4 [0/6320 (0%)]	Loss: 0.235804 , Overall Accuracy : 90.625
# Accuracy as in paper:  0.9879807692307693
# Train Fold/Epoch: 5/5 [0/6320 (0%)]	Loss: 0.274478 , Overall Accuracy : 92.1875
# Accuracy as in paper:  0.9951923076923077
# Train Fold/Epoch: 5/6 [0/6320 (0%)]	Loss: 0.149175 , Overall Accuracy : 96.875
# Accuracy as in paper:  0.9855769230769231
# Train Fold/Epoch: 5/7 [0/6320 (0%)]	Loss: 0.287787 , Overall Accuracy : 90.625
# Accuracy as in paper:  0.9739583333333334
# Train Fold/Epoch: 5/8 [0/6320 (0%)]	Loss: 0.428959 , Overall Accuracy : 84.375
# Accuracy as in paper:  0.9975961538461539
# Train Fold/Epoch: 5/9 [0/6320 (0%)]	Loss: 0.093547 , Overall Accuracy : 98.4375
# validate 1
# Accuracy as in paper:  1.0
# Validation Fold: 1 [0/6320 (0%)]	Loss: 0.015410 , Overall Accuracy : 100.0
# Overall Accuracy:  97.80458860759494
# Overall Test Accuracy : 68.1923076923077
# Accuracy as in paper:  0.9423076923076923
# ------------fold no---------1----------------------
# Accuracy as in paper:  0.8653846153846154
# Train Fold/Epoch: 1/1 [0/6320 (0%)]	Loss: 2.584190 , Overall Accuracy : 12.5
# Accuracy as in paper:  0.8533653846153846
# Train Fold/Epoch: 1/2 [0/6320 (0%)]	Loss: 2.940957 , Overall Accuracy : 4.6875
# Accuracy as in paper:  0.8701923076923077
# Train Fold/Epoch: 1/3 [0/6320 (0%)]	Loss: 2.433596 , Overall Accuracy : 15.625
# Accuracy as in paper:  0.8653846153846154
# Train Fold/Epoch: 1/4 [0/6320 (0%)]	Loss: 2.321056 , Overall Accuracy : 12.5
# Accuracy as in paper:  0.8677884615384616
# Train Fold/Epoch: 1/5 [0/6320 (0%)]	Loss: 2.600829 , Overall Accuracy : 14.0625
# Accuracy as in paper:  0.8822115384615384
# Train Fold/Epoch: 1/6 [0/6320 (0%)]	Loss: 2.058274 , Overall Accuracy : 23.4375
# Accuracy as in paper:  0.8725961538461539
# Train Fold/Epoch: 1/7 [0/6320 (0%)]	Loss: 2.278007 , Overall Accuracy : 17.1875
# Accuracy as in paper:  0.9110576923076923
# Train Fold/Epoch: 1/8 [0/6320 (0%)]	Loss: 1.797536 , Overall Accuracy : 42.1875
# Accuracy as in paper:  0.8894230769230769
# Train Fold/Epoch: 1/9 [0/6320 (0%)]	Loss: 1.859476 , Overall Accuracy : 28.125
# ------------fold no---------2----------------------
# ------------fold no---------3----------------------
# Accuracy as in paper:  0.8918269230769231
# Train Fold/Epoch: 3/1 [0/6320 (0%)]	Loss: 2.062984 , Overall Accuracy : 29.6875
# Accuracy as in paper:  0.9038461538461539
# Train Fold/Epoch: 3/2 [0/6320 (0%)]	Loss: 1.848624 , Overall Accuracy : 37.5
# Accuracy as in paper:  0.8966346153846154
# Train Fold/Epoch: 3/3 [0/6320 (0%)]	Loss: 2.075178 , Overall Accuracy : 32.8125
# Accuracy as in paper:  0.8894230769230769
# Train Fold/Epoch: 3/4 [0/6320 (0%)]	Loss: 1.945943 , Overall Accuracy : 28.125
# Accuracy as in paper:  0.8894230769230769
# Train Fold/Epoch: 3/5 [0/6320 (0%)]	Loss: 1.874486 , Overall Accuracy : 28.125
# Accuracy as in paper:  0.8846153846153846
# Train Fold/Epoch: 3/6 [0/6320 (0%)]	Loss: 1.939173 , Overall Accuracy : 25.0
# Accuracy as in paper:  0.8870192307692307
# Train Fold/Epoch: 3/7 [0/6320 (0%)]	Loss: 1.917874 , Overall Accuracy : 26.5625
# Accuracy as in paper:  0.8966346153846154
# Train Fold/Epoch: 3/8 [0/6320 (0%)]	Loss: 1.742206 , Overall Accuracy : 32.8125
# Accuracy as in paper:  0.8802083333333334
# Train Fold/Epoch: 3/9 [0/6320 (0%)]	Loss: 1.766036 , Overall Accuracy : 28.125
# ------------fold no---------4----------------------
# Accuracy as in paper:  0.8918269230769231
# Train Fold/Epoch: 4/1 [0/6320 (0%)]	Loss: 1.853912 , Overall Accuracy : 29.6875
# Accuracy as in paper:  0.8990384615384616
# Train Fold/Epoch: 4/2 [0/6320 (0%)]	Loss: 1.773432 , Overall Accuracy : 34.375
# Accuracy as in paper:  0.8942307692307693
# Train Fold/Epoch: 4/3 [0/6320 (0%)]	Loss: 1.790776 , Overall Accuracy : 31.25
# Accuracy as in paper:  0.8774038461538461
# Train Fold/Epoch: 4/4 [0/6320 (0%)]	Loss: 2.317227 , Overall Accuracy : 20.3125
# Accuracy as in paper:  0.8942307692307693
# Train Fold/Epoch: 4/5 [0/6320 (0%)]	Loss: 1.745654 , Overall Accuracy : 31.25
# Accuracy as in paper:  0.8942307692307693
# Train Fold/Epoch: 4/6 [0/6320 (0%)]	Loss: 1.727278 , Overall Accuracy : 31.25
# Accuracy as in paper:  0.8918269230769231
# Train Fold/Epoch: 4/7 [0/6320 (0%)]	Loss: 1.597303 , Overall Accuracy : 29.6875
# Accuracy as in paper:  0.9086538461538461
# Train Fold/Epoch: 4/8 [0/6320 (0%)]	Loss: 1.632034 , Overall Accuracy : 40.625
# Accuracy as in paper:  0.8870192307692307
# Train Fold/Epoch: 4/9 [0/6320 (0%)]	Loss: 1.848065 , Overall Accuracy : 26.5625
# ------------fold no---------5----------------------
# Accuracy as in paper:  0.8870192307692307
# Train Fold/Epoch: 5/1 [0/6320 (0%)]	Loss: 2.132163 , Overall Accuracy : 26.5625
# Accuracy as in paper:  0.9086538461538461
# Train Fold/Epoch: 5/2 [0/6320 (0%)]	Loss: 1.556515 , Overall Accuracy : 40.625
# Accuracy as in paper:  0.8942307692307693
# Train Fold/Epoch: 5/3 [0/6320 (0%)]	Loss: 1.660756 , Overall Accuracy : 31.25
# Accuracy as in paper:  0.9134615384615384
# Train Fold/Epoch: 5/4 [0/6320 (0%)]	Loss: 1.691400 , Overall Accuracy : 43.75
# Accuracy as in paper:  0.9110576923076923
# Train Fold/Epoch: 5/5 [0/6320 (0%)]	Loss: 1.564021 , Overall Accuracy : 42.1875
# Accuracy as in paper:  0.9230769230769231
# Train Fold/Epoch: 5/6 [0/6320 (0%)]	Loss: 1.407703 , Overall Accuracy : 50.0
# Accuracy as in paper:  0.9110576923076923
# Train Fold/Epoch: 5/7 [0/6320 (0%)]	Loss: 1.406958 , Overall Accuracy : 42.1875
# Accuracy as in paper:  0.9158653846153846
# Train Fold/Epoch: 5/8 [0/6320 (0%)]	Loss: 1.263666 , Overall Accuracy : 45.3125
# Accuracy as in paper:  0.9230769230769231
# Train Fold/Epoch: 5/9 [0/6320 (0%)]	Loss: 1.381060 , Overall Accuracy : 50.0
# validate 2
# Accuracy as in paper:  0.9134615384615384
# Validation Fold: 2 [0/6320 (0%)]	Loss: 1.280269 , Overall Accuracy : 43.75
# Overall Accuracy:  44.026898734177216
# Overall Test Accuracy : 35.53846153846154
# Accuracy as in paper:  0.9038461538461539
# ------------fold no---------1----------------------
# Accuracy as in paper:  0.8701923076923077
# Train Fold/Epoch: 1/1 [0/6320 (0%)]	Loss: 2.530954 , Overall Accuracy : 15.625
# Accuracy as in paper:  0.8557692307692307
# Train Fold/Epoch: 1/2 [0/6320 (0%)]	Loss: 3.008247 , Overall Accuracy : 6.25
# Accuracy as in paper:  0.8798076923076923
# Train Fold/Epoch: 1/3 [0/6320 (0%)]	Loss: 2.535746 , Overall Accuracy : 21.875
# Accuracy as in paper:  0.8854166666666666
# Train Fold/Epoch: 1/4 [0/6320 (0%)]	Loss: 1.971458 , Overall Accuracy : 31.25
# Accuracy as in paper:  0.9014423076923077
# Train Fold/Epoch: 1/5 [0/6320 (0%)]	Loss: 1.936493 , Overall Accuracy : 35.9375
# Accuracy as in paper:  0.8725961538461539
# Train Fold/Epoch: 1/6 [0/6320 (0%)]	Loss: 2.117607 , Overall Accuracy : 17.1875
# Accuracy as in paper:  0.8918269230769231
# Train Fold/Epoch: 1/7 [0/6320 (0%)]	Loss: 1.851363 , Overall Accuracy : 29.6875
# Accuracy as in paper:  0.8822115384615384
# Train Fold/Epoch: 1/8 [0/6320 (0%)]	Loss: 2.227504 , Overall Accuracy : 23.4375
# Accuracy as in paper:  0.8846153846153846
# Train Fold/Epoch: 1/9 [0/6320 (0%)]	Loss: 2.004756 , Overall Accuracy : 25.0
# ------------fold no---------2----------------------
# Accuracy as in paper:  0.8918269230769231
# Train Fold/Epoch: 2/1 [0/6320 (0%)]	Loss: 1.917004 , Overall Accuracy : 29.6875
# Accuracy as in paper:  0.8798076923076923
# Train Fold/Epoch: 2/2 [0/6320 (0%)]	Loss: 2.064655 , Overall Accuracy : 21.875
# Accuracy as in paper:  0.8966346153846154
# Train Fold/Epoch: 2/3 [0/6320 (0%)]	Loss: 1.787105 , Overall Accuracy : 32.8125
# Accuracy as in paper:  0.8918269230769231
# Train Fold/Epoch: 2/4 [0/6320 (0%)]	Loss: 1.713032 , Overall Accuracy : 29.6875
# Accuracy as in paper:  0.8894230769230769
# Train Fold/Epoch: 2/5 [0/6320 (0%)]	Loss: 2.178750 , Overall Accuracy : 28.125
# Accuracy as in paper:  0.8966346153846154
# Train Fold/Epoch: 2/6 [0/6320 (0%)]	Loss: 1.833781 , Overall Accuracy : 32.8125
# Accuracy as in paper:  0.8701923076923077
# Train Fold/Epoch: 2/7 [0/6320 (0%)]	Loss: 2.195414 , Overall Accuracy : 15.625
# Accuracy as in paper:  0.9110576923076923
# Train Fold/Epoch: 2/8 [0/6320 (0%)]	Loss: 1.661649 , Overall Accuracy : 42.1875
# Accuracy as in paper:  0.9110576923076923
# Train Fold/Epoch: 2/9 [0/6320 (0%)]	Loss: 1.628623 , Overall Accuracy : 42.1875
# ------------fold no---------3----------------------
# ------------fold no---------4----------------------
# Accuracy as in paper:  0.8990384615384616
# Train Fold/Epoch: 4/1 [0/6320 (0%)]	Loss: 1.813826 , Overall Accuracy : 34.375
# Accuracy as in paper:  0.8966346153846154
# Train Fold/Epoch: 4/2 [0/6320 (0%)]	Loss: 1.678905 , Overall Accuracy : 32.8125
# Accuracy as in paper:  0.9110576923076923
# Train Fold/Epoch: 4/3 [0/6320 (0%)]	Loss: 1.398668 , Overall Accuracy : 42.1875
# Accuracy as in paper:  0.9110576923076923
# Train Fold/Epoch: 4/4 [0/6320 (0%)]	Loss: 1.668482 , Overall Accuracy : 42.1875
# Accuracy as in paper:  0.9302884615384616
# Train Fold/Epoch: 4/5 [0/6320 (0%)]	Loss: 1.216880 , Overall Accuracy : 54.6875
# Accuracy as in paper:  0.9278846153846154
# Train Fold/Epoch: 4/6 [0/6320 (0%)]	Loss: 1.341364 , Overall Accuracy : 53.125
# Accuracy as in paper:  0.9254807692307693
# Train Fold/Epoch: 4/7 [0/6320 (0%)]	Loss: 1.358124 , Overall Accuracy : 51.5625
# Accuracy as in paper:  0.9278846153846154
# Train Fold/Epoch: 4/8 [0/6320 (0%)]	Loss: 1.229505 , Overall Accuracy : 53.125
# Accuracy as in paper:  0.9206730769230769
# Train Fold/Epoch: 4/9 [0/6320 (0%)]	Loss: 1.281055 , Overall Accuracy : 48.4375
# ------------fold no---------5----------------------
# Accuracy as in paper:  0.9543269230769231
# Train Fold/Epoch: 5/1 [0/6320 (0%)]	Loss: 1.032169 , Overall Accuracy : 70.3125
# Accuracy as in paper:  0.9278846153846154
# Train Fold/Epoch: 5/2 [0/6320 (0%)]	Loss: 1.203129 , Overall Accuracy : 53.125
# Accuracy as in paper:  0.9278846153846154
# Train Fold/Epoch: 5/3 [0/6320 (0%)]	Loss: 1.206787 , Overall Accuracy : 53.125
# Accuracy as in paper:  0.9471153846153846
# Train Fold/Epoch: 5/4 [0/6320 (0%)]	Loss: 0.881979 , Overall Accuracy : 65.625
# Accuracy as in paper:  0.9639423076923077
# Train Fold/Epoch: 5/5 [0/6320 (0%)]	Loss: 0.688015 , Overall Accuracy : 76.5625
# Accuracy as in paper:  0.9350961538461539
# Train Fold/Epoch: 5/6 [0/6320 (0%)]	Loss: 1.073191 , Overall Accuracy : 57.8125
# Accuracy as in paper:  0.9543269230769231
# Train Fold/Epoch: 5/7 [0/6320 (0%)]	Loss: 0.849249 , Overall Accuracy : 70.3125
# Accuracy as in paper:  0.96875
# Train Fold/Epoch: 5/8 [0/6320 (0%)]	Loss: 0.638963 , Overall Accuracy : 79.6875
# Accuracy as in paper:  0.9471153846153846
# Train Fold/Epoch: 5/9 [0/6320 (0%)]	Loss: 1.015174 , Overall Accuracy : 65.625
# validate 3
# Accuracy as in paper:  0.9206730769230769
# Validation Fold: 3 [0/6320 (0%)]	Loss: 1.736928 , Overall Accuracy : 48.4375
# Overall Accuracy:  36.4121835443038
# Overall Test Accuracy : 31.884615384615383
# Accuracy as in paper:  0.8961538461538462
# ------------fold no---------1----------------------
# Accuracy as in paper:  0.8629807692307693
# Train Fold/Epoch: 1/1 [0/6320 (0%)]	Loss: 2.550208 , Overall Accuracy : 10.9375
# Accuracy as in paper:  0.8557692307692307
# Train Fold/Epoch: 1/2 [0/6320 (0%)]	Loss: 2.728671 , Overall Accuracy : 6.25
# Accuracy as in paper:  0.8697916666666666
# Train Fold/Epoch: 1/3 [0/6320 (0%)]	Loss: 2.033061 , Overall Accuracy : 21.875
# Accuracy as in paper:  0.8918269230769231
# Train Fold/Epoch: 1/4 [0/6320 (0%)]	Loss: 1.932436 , Overall Accuracy : 29.6875
# Accuracy as in paper:  0.8870192307692307
# Train Fold/Epoch: 1/5 [0/6320 (0%)]	Loss: 2.071849 , Overall Accuracy : 26.5625
# Accuracy as in paper:  0.8870192307692307
# Train Fold/Epoch: 1/6 [0/6320 (0%)]	Loss: 2.416911 , Overall Accuracy : 26.5625
# Accuracy as in paper:  0.9038461538461539
# Train Fold/Epoch: 1/7 [0/6320 (0%)]	Loss: 1.808508 , Overall Accuracy : 37.5
# Accuracy as in paper:  0.9014423076923077
# Train Fold/Epoch: 1/8 [0/6320 (0%)]	Loss: 1.782259 , Overall Accuracy : 35.9375
# Accuracy as in paper:  0.8894230769230769
# Train Fold/Epoch: 1/9 [0/6320 (0%)]	Loss: 1.993632 , Overall Accuracy : 28.125
# ------------fold no---------2----------------------
# Accuracy as in paper:  0.8822115384615384
# Train Fold/Epoch: 2/1 [0/6320 (0%)]	Loss: 1.903705 , Overall Accuracy : 23.4375
# Accuracy as in paper:  0.9038461538461539
# Train Fold/Epoch: 2/2 [0/6320 (0%)]	Loss: 1.697212 , Overall Accuracy : 37.5
# Accuracy as in paper:  0.8966346153846154
# Train Fold/Epoch: 2/3 [0/6320 (0%)]	Loss: 1.920122 , Overall Accuracy : 32.8125
# Accuracy as in paper:  0.8846153846153846
# Train Fold/Epoch: 2/4 [0/6320 (0%)]	Loss: 1.884484 , Overall Accuracy : 25.0
# Accuracy as in paper:  0.8966346153846154
# Train Fold/Epoch: 2/5 [0/6320 (0%)]	Loss: 1.793175 , Overall Accuracy : 32.8125
# Accuracy as in paper:  0.8966346153846154
# Train Fold/Epoch: 2/6 [0/6320 (0%)]	Loss: 1.988936 , Overall Accuracy : 32.8125
# Accuracy as in paper:  0.8870192307692307
# Train Fold/Epoch: 2/7 [0/6320 (0%)]	Loss: 1.914708 , Overall Accuracy : 26.5625
# Accuracy as in paper:  0.8918269230769231
# Train Fold/Epoch: 2/8 [0/6320 (0%)]	Loss: 1.735820 , Overall Accuracy : 29.6875
# Accuracy as in paper:  0.8822115384615384
# Train Fold/Epoch: 2/9 [0/6320 (0%)]	Loss: 2.143353 , Overall Accuracy : 23.4375
# ------------fold no---------3----------------------
# Accuracy as in paper:  0.8846153846153846
# Train Fold/Epoch: 3/1 [0/6320 (0%)]	Loss: 2.049971 , Overall Accuracy : 25.0
# Accuracy as in paper:  0.8966346153846154
# Train Fold/Epoch: 3/2 [0/6320 (0%)]	Loss: 1.887879 , Overall Accuracy : 32.8125
# Accuracy as in paper:  0.8990384615384616
# Train Fold/Epoch: 3/3 [0/6320 (0%)]	Loss: 1.764400 , Overall Accuracy : 34.375
# Accuracy as in paper:  0.8846153846153846
# Train Fold/Epoch: 3/4 [0/6320 (0%)]	Loss: 1.770885 , Overall Accuracy : 25.0
# Accuracy as in paper:  0.9014423076923077
# Train Fold/Epoch: 3/5 [0/6320 (0%)]	Loss: 1.794376 , Overall Accuracy : 35.9375
# Accuracy as in paper:  0.9110576923076923
# Train Fold/Epoch: 3/6 [0/6320 (0%)]	Loss: 1.933603 , Overall Accuracy : 42.1875
# Accuracy as in paper:  0.9038461538461539
# Train Fold/Epoch: 3/7 [0/6320 (0%)]	Loss: 1.756167 , Overall Accuracy : 37.5
# Accuracy as in paper:  0.9038461538461539
# Train Fold/Epoch: 3/8 [0/6320 (0%)]	Loss: 1.924000 , Overall Accuracy : 37.5
# Accuracy as in paper:  0.9182692307692307
# Train Fold/Epoch: 3/9 [0/6320 (0%)]	Loss: 1.626493 , Overall Accuracy : 46.875
# ------------fold no---------4----------------------
# ------------fold no---------5----------------------
# Accuracy as in paper:  0.90625
# Train Fold/Epoch: 5/1 [0/6320 (0%)]	Loss: 1.726449 , Overall Accuracy : 39.0625
# Accuracy as in paper:  0.9182692307692307
# Train Fold/Epoch: 5/2 [0/6320 (0%)]	Loss: 1.340296 , Overall Accuracy : 46.875
# Accuracy as in paper:  0.9206730769230769
# Train Fold/Epoch: 5/3 [0/6320 (0%)]	Loss: 1.425960 , Overall Accuracy : 48.4375
# Accuracy as in paper:  0.9495192307692307
# Train Fold/Epoch: 5/4 [0/6320 (0%)]	Loss: 0.994449 , Overall Accuracy : 67.1875
# Accuracy as in paper:  0.9447115384615384
# Train Fold/Epoch: 5/5 [0/6320 (0%)]	Loss: 1.136636 , Overall Accuracy : 64.0625
# Accuracy as in paper:  0.9423076923076923
# Train Fold/Epoch: 5/6 [0/6320 (0%)]	Loss: 1.106534 , Overall Accuracy : 62.5
# Accuracy as in paper:  0.96875
# Train Fold/Epoch: 5/7 [0/6320 (0%)]	Loss: 0.766332 , Overall Accuracy : 79.6875
# Accuracy as in paper:  0.9375
# Train Fold/Epoch: 5/8 [0/6320 (0%)]	Loss: 1.251911 , Overall Accuracy : 59.375
# Accuracy as in paper:  0.9663461538461539
# Train Fold/Epoch: 5/9 [0/6320 (0%)]	Loss: 0.716337 , Overall Accuracy : 78.125
# validate 4
# Accuracy as in paper:  0.9348958333333334
# Validation Fold: 4 [0/6320 (0%)]	Loss: 1.138983 , Overall Accuracy : 60.9375
# Overall Accuracy:  58.10917721518988
# Overall Test Accuracy : 49.07692307692308
# Accuracy as in paper:  0.9
# ------------fold no---------1----------------------
# Accuracy as in paper:  0.8605769230769231
# Train Fold/Epoch: 1/1 [0/6320 (0%)]	Loss: 2.563804 , Overall Accuracy : 9.375
# Accuracy as in paper:  0.8701923076923077
# Train Fold/Epoch: 1/2 [0/6320 (0%)]	Loss: 2.702867 , Overall Accuracy : 15.625
# Accuracy as in paper:  0.8870192307692307
# Train Fold/Epoch: 1/3 [0/6320 (0%)]	Loss: 2.164127 , Overall Accuracy : 26.5625
# Accuracy as in paper:  0.8894230769230769
# Train Fold/Epoch: 1/4 [0/6320 (0%)]	Loss: 1.978003 , Overall Accuracy : 28.125
# Accuracy as in paper:  0.875
# Train Fold/Epoch: 1/5 [0/6320 (0%)]	Loss: 2.314833 , Overall Accuracy : 18.75
# Accuracy as in paper:  0.8701923076923077
# Train Fold/Epoch: 1/6 [0/6320 (0%)]	Loss: 1.986743 , Overall Accuracy : 15.625
# Accuracy as in paper:  0.8870192307692307
# Train Fold/Epoch: 1/7 [0/6320 (0%)]	Loss: 1.958654 , Overall Accuracy : 26.5625
# Accuracy as in paper:  0.875
# Train Fold/Epoch: 1/8 [0/6320 (0%)]	Loss: 1.851358 , Overall Accuracy : 18.75
# Accuracy as in paper:  0.8942307692307693
# Train Fold/Epoch: 1/9 [0/6320 (0%)]	Loss: 1.841594 , Overall Accuracy : 31.25
# ------------fold no---------2----------------------
# Accuracy as in paper:  0.9086538461538461
# Train Fold/Epoch: 2/1 [0/6320 (0%)]	Loss: 1.877458 , Overall Accuracy : 40.625
# Accuracy as in paper:  0.9086538461538461
# Train Fold/Epoch: 2/2 [0/6320 (0%)]	Loss: 1.847272 , Overall Accuracy : 40.625
# Accuracy as in paper:  0.8894230769230769
# Train Fold/Epoch: 2/3 [0/6320 (0%)]	Loss: 1.752954 , Overall Accuracy : 28.125
# Accuracy as in paper:  0.9110576923076923
# Train Fold/Epoch: 2/4 [0/6320 (0%)]	Loss: 1.674996 , Overall Accuracy : 42.1875
# Accuracy as in paper:  0.9086538461538461
# Train Fold/Epoch: 2/5 [0/6320 (0%)]	Loss: 1.681178 , Overall Accuracy : 40.625
# Accuracy as in paper:  0.9014423076923077
# Train Fold/Epoch: 2/6 [0/6320 (0%)]	Loss: 1.703203 , Overall Accuracy : 35.9375
# Accuracy as in paper:  0.90625
# Train Fold/Epoch: 2/7 [0/6320 (0%)]	Loss: 1.776706 , Overall Accuracy : 39.0625
# Accuracy as in paper:  0.8894230769230769
# Train Fold/Epoch: 2/8 [0/6320 (0%)]	Loss: 1.848810 , Overall Accuracy : 28.125
# Accuracy as in paper:  0.9278846153846154
# Train Fold/Epoch: 2/9 [0/6320 (0%)]	Loss: 1.495591 , Overall Accuracy : 53.125
# ------------fold no---------3----------------------
# Accuracy as in paper:  0.9110576923076923
# Train Fold/Epoch: 3/1 [0/6320 (0%)]	Loss: 1.725270 , Overall Accuracy : 42.1875
# Accuracy as in paper:  0.9158653846153846
# Train Fold/Epoch: 3/2 [0/6320 (0%)]	Loss: 1.448220 , Overall Accuracy : 45.3125
# Accuracy as in paper:  0.9014423076923077
# Train Fold/Epoch: 3/3 [0/6320 (0%)]	Loss: 1.541348 , Overall Accuracy : 35.9375
# Accuracy as in paper:  0.8918269230769231
# Train Fold/Epoch: 3/4 [0/6320 (0%)]	Loss: 1.642079 , Overall Accuracy : 29.6875
# Accuracy as in paper:  0.9086538461538461
# Train Fold/Epoch: 3/5 [0/6320 (0%)]	Loss: 1.477180 , Overall Accuracy : 40.625
# Accuracy as in paper:  0.9110576923076923
# Train Fold/Epoch: 3/6 [0/6320 (0%)]	Loss: 1.515504 , Overall Accuracy : 42.1875
# Accuracy as in paper:  0.9278846153846154
# Train Fold/Epoch: 3/7 [0/6320 (0%)]	Loss: 1.231472 , Overall Accuracy : 53.125
# Accuracy as in paper:  0.8966346153846154
# Train Fold/Epoch: 3/8 [0/6320 (0%)]	Loss: 1.601584 , Overall Accuracy : 32.8125
# Accuracy as in paper:  0.9423076923076923
# Train Fold/Epoch: 3/9 [0/6320 (0%)]	Loss: 1.113470 , Overall Accuracy : 62.5
# ------------fold no---------4----------------------
# Accuracy as in paper:  0.9495192307692307
# Train Fold/Epoch: 4/1 [0/6320 (0%)]	Loss: 1.021467 , Overall Accuracy : 67.1875
# Accuracy as in paper:  0.9278846153846154
# Train Fold/Epoch: 4/2 [0/6320 (0%)]	Loss: 1.277628 , Overall Accuracy : 53.125
# Accuracy as in paper:  0.9302884615384616
# Train Fold/Epoch: 4/3 [0/6320 (0%)]	Loss: 1.088326 , Overall Accuracy : 54.6875
# Accuracy as in paper:  0.9447115384615384
# Train Fold/Epoch: 4/4 [0/6320 (0%)]	Loss: 1.055916 , Overall Accuracy : 64.0625
# Accuracy as in paper:  0.9423076923076923
# Train Fold/Epoch: 4/5 [0/6320 (0%)]	Loss: 0.937210 , Overall Accuracy : 62.5
# Accuracy as in paper:  0.9639423076923077
# Train Fold/Epoch: 4/6 [0/6320 (0%)]	Loss: 0.791958 , Overall Accuracy : 76.5625
# Accuracy as in paper:  0.9296875
# Train Fold/Epoch: 4/7 [0/6320 (0%)]	Loss: 0.991057 , Overall Accuracy : 57.8125
# Accuracy as in paper:  0.9399038461538461
# Train Fold/Epoch: 4/8 [0/6320 (0%)]	Loss: 1.017937 , Overall Accuracy : 60.9375
# Accuracy as in paper:  0.9375
# Train Fold/Epoch: 4/9 [0/6320 (0%)]	Loss: 0.899339 , Overall Accuracy : 59.375
# ------------fold no---------5----------------------
# validate 5
# Accuracy as in paper:  0.96875
# Validation Fold: 5 [0/6320 (0%)]	Loss: 0.600363 , Overall Accuracy : 79.6875
# Overall Accuracy:  70.49050632911393
# Overall Test Accuracy : 54.769230769230774
# Accuracy as in paper:  0.9230769230769231

# %% [markdown]
# # Testing (Already done with Validation)

# %%
# total_loss_i = 0
# total=0.0
# correct=0.0
# model.eval()
# for i, batch in enumerate(test_dataloader):
#     x,y=batch
#     logits = model(x.to(device))
#     loss = loss_function(logits,y.cuda())
#     total_loss_i += loss.item()
#     _, predicted = torch.max(logits.data, 1)
#     total += y.size(0)
#     correct += (predicted.cpu() == y).sum().item()
#     print("Iter : {}  Test Loss : {}".format(i,loss.item()))
    
# # total_loss_e+=total_loss_i/len(test_dataloader)
# print(" Accuracy : {}".format( (100 * (correct / total))))

# %% [markdown]
# # Test the Model

# %%
# x,y = next(iter(test_dataloader))
# print("Ground Truth:", y)
# new_arr = x.to(device)
# preds = model(new_arr)
# print("Predictions", torch.max(preds, dim =1 ))
# Out:
# ('Ground Truth:', tensor([ 6,  1,  5,  8,  2,  7,  3, 12,  1, 10,  0,  8,  0, 11,  4, 11,  4,  5,
#          0,  9,  5,  8, 10, 11,  5,  3,  0, 10,  3,  8,  5,  5]))
# ('Predictions', torch.return_types.max(
# values=tensor([ 7.1839, 10.2467, 26.1294,  9.4398,  7.1561,  9.4496, 10.6262, 17.2464,
#         19.4904,  3.7054, 18.4795,  6.4708, 26.0225, 11.1400,  6.3326, 14.0131,
#          7.4746,  6.4471, 16.5906,  8.3950,  8.9410,  5.3150, 12.0303,  5.2834,
#         22.6050,  7.6941, 22.2037, 11.0065,  9.8128, 12.8329, 21.3922, 24.8926],
#        device='cuda:0', grad_fn=<MaxBackward0>),
# indices=tensor([ 6,  7,  5,  8,  8,  7,  3, 12,  1,  3,  0,  8,  0, 11,  4, 11,  8,  8,
#          0,  8,  5,  8, 10,  7,  5,  7,  0,  5,  2,  2,  5,  5],
#        device='cuda:0')))
